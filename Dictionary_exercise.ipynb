# %% [markdown]
# <a href="https://colab.research.google.com/github/Manal5664/Python-Development/blob/master/Dictionary_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={1:"a","b":2,"c":[1,2,3]}

# %%
len(d)
# Out:
# 3

# %%
d={"brand":"ford", "model":"Mustang","year":1964}

# %%
d["brand"]
# Out:
# 'ford'

# %%
print(d.get(1))
# Out:
# None

# %%
d.get("brand")
# Out:
# 'ford'

# %%
# write a program to print only uniques values from list
l=[1,2,2,2,3,5,6,8,9,4,2]

# %%
s= set(l)
for i in s:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 8
# 9

# %%
for x in l:
  if l.count(x)==1:
    print(x)
# Out:
# 1
# 3
# 5
# 6
# 8
# 9
# 4

# %%
d={1:"a","b":2,"c":[1,2,3]}
list(d.keys())
# Out:
# [1, 'b', 'c']

# %%
d.values()
# Out:
# dict_values(['a', 2, [1, 2, 3]])

# %%
d.items()
# Out:
# dict_items([(1, 'a'), ('b', 2), ('c', [1, 2, 3])])

# %%
if "b" in d:
    print("yes,it is not one of the keys in the dictionary")
else:
    print("not in the list")
# Out:
# yes,it is not one of the keys in the dictionary

# %%
d["b"]=4
print(d)
# Out:
# {1: 'a', 'b': 4, 'c': [1, 2, 3]}

# %%
d.update({'4':'altis'})
print(d)
# Out:
# {1: 'a', 'b': 4, 'c': [1, 2, 3], '4': 'altis'}

# %%
# pop
d.pop("b")
d
# Out:
# {1: 'a', 'c': [1, 2, 3], '4': 'altis'}

# %%
# pop item
d.popitem()
# Out:
# ('4', 'altis')

# %%
# del
del d['c']

# %%
print(d)
# Out:
# {1: 'a'}

# %%
# Nested Dictionary

myfam={"child1":{"name":"Sana","year":2008},
       "child2":{"name":"Navaid","year":2009},
       "child3":{"name":"Ali","year":2005}
       }

# %%
myfam["child1"]
# Out:
# {'name': 'Sana', 'year': 2008}

# %%
# change name sana to roma
myfam["child1"]["name"]="roma"

# %%
myfam
# Out:
# {'child1': {'name': 'roma', 'year': 2008},
#  'child2': {'name': 'Navaid', 'year': 2009},
#  'child3': {'name': 'Ali', 'year': 2005}}

# %%
# task 1 generate a code which takes a list of a number is provides sqaures of these numbers in a new list

num=[1,2,3]
lst=[]
for i in num:
    z=i*i
    lst.append(z)
print(lst)
# Out:
# [1, 4, 9]

# %%
# write  code which takes a list of numbers as in input from users an check generate a list of numbers which are dvisible by 2 .
# those numbrs which are divisible by 2 will be saves d a in new list
lst=[]
for i in range(1,10):
    if i%2==0:
        lst.append(i)
print(lst)
