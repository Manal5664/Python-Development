# %%
# Sets
# the way we are assignning the value its not stored like that
# this is unordered collection because they don;t have indexes
# curly brackets
# unique values

# %%
s={1,2,3,"a",2.5,4j,3}
print(s)
# Out:
# {1, 2.5, 3, 2, 'a', 4j}

# %%
# add
s={"apple","banaan","cherry"}

# %%
s
# Out:
# {'apple', 'banaan', 'cherry'}

# %%
s.add("orange")

# %%
s
# Out:
# {'apple', 'banaan', 'cherry', 'orange'}

# %%
y={"google","apple","banana"}

# %%
print(s,y)
# Out:
# {'cherry', 'banaan', 'apple', 'orange'} {'banana', 'google', 'apple'}

# %%
s.update(y)

# %%
s
# Out:
# {'apple', 'banaan', 'banana', 'cherry', 'google', 'orange'}

# %%
# difference
print(s)
print(y)
# Out:
# {'banana', 'cherry', 'banaan', 'google', 'apple', 'orange'}
# {'banana', 'google', 'apple'}

# %%
z=s.difference(y)
print(z)
# Out:
# {'cherry', 'banaan', 'orange'}

# %%
# Remove
print(s)
# Out:
# {'banana', 'cherry', 'banaan', 'google', 'apple', 'orange'}

# %%
s.remove("google")

# %%
print(s)
# Out:
# {'banana', 'cherry', 'banaan', 'apple', 'orange'}

# %%
# remove(it will give error when value is not in data)
# discard(it will not give an error)

# %%
s.discard("googles")

# %%
s
# Out:
# {'apple', 'banaan', 'banana', 'cherry', 'orange'}

# %%
# pop()

# %%
s.pop()
# Out:
# 'banana'

# %%
s
# Out:
# {'apple', 'banaan', 'cherry', 'orange'}

# %%
s
# Out:
# {'apple', 'banaan', 'cherry', 'orange'}

# %%
s={'apple', 'banaan', 'cherry', 'orange'}

# %%
s
# Out:
# {'apple', 'banaan', 'cherry', 'orange'}

# %%
s.pop()
# Out:
# 'cherry'

# %%
s
# Out:
# {'apple', 'banaan', 'orange'}

# %%
s={'banana', 'cherry', 'banaan', 'google', 'apple', 'orange'}
y={'banana', 'google', 'apple'}

# %%
z=s.union(y)

# %%
print(z)
# Out:
# {'google', 'banana', 'cherry', 'banaan', 'apple', 'orange'}

# %%
s={'banana', 'cherry', 'banaan', 'google', 'apple', 'orange'}
y={'banana', 'google', 'apple'}
z=s.intersection(y)
print(z)
# Out:
# {'banana', 'google', 'apple'}
