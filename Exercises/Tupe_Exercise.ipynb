# %%
# Tuple contain hetrogeneuse data and not necessary ()
# Mutable you can't add element , remove
#  we cannot the change the size of tuple
t1=(1,"a",2.5,4j,[5,6])

# %%
t2=1,2,3
type(t2)
# Out:
# tuple

# %%
t3=1,
type(t3)
# Out:
# tuple

# %%
t1[0]
# Out:
# 1

# %%
t1[-1]
# Out:
# [5, 6]

# %%
t4=1,2,3,7,8,9,6,0,6
t4.count(6)
# Out:
# 2

# %%
t4.index(6)
# Out:
# 7

# %%
# t4.append(7)
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t4
# Out:
# (1, 2, 3, 7, 8, 9, 6, 0, 6)

# %%
l4=list(t4)

# %%
l4
# Out:
# [1, 2, 3, 7, 8, 9, 6, 0, 6]

# %%
l4.append(10)

# %%
t5=tuple(l4)
t5
# Out:
# (1, 2, 3, 7, 8, 9, 6, 0, 6, 10)
