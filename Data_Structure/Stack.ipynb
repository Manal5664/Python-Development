# %% [markdown]
# # Stack LIFO

# %%
stack = []
stack.append(10)
stack.append(20)
stack.pop()
print(stack)
# Out:
# [10]

# %%
stack = []

# push
stack.append(10)
stack.append(20)
stack.append(30)

# %%
# pop
stack.pop()

# peek
print(stack[-1])

print(stack)
# Out:
# 20
# [10, 20]
