# %%
my_set = {1, 2, 3, 4}
print(my_set)
# Out:
# {1, 2, 3, 4}

# %%
# Duplicate remove automatically
s = {1, 2, 2, 3}
print(s)
# Out:
# {1, 2, 3}

# %%
# Set operation

a = {1, 2, 3}
b = {3, 4, 5}

print(a.union(b))
print(a.intersection(b))
print(a.difference(b))
# Out:
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
