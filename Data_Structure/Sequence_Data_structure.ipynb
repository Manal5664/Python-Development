# %%
text = "Python"

# %%
# Access Character
print(text[0])
print(text[-1])
# Out:
# P
# n

# %%
# String Methods
print(text.upper())
print(text.lower())
print(text.replace("Py", "My"))
# Out:
# PYTHON
# python
# Mython

# %%
# Loop String
for ch in text:
    print(ch)
# Out:
# P
# y
# t
# h
# o
# n
