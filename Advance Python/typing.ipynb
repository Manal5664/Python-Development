# %%
# Python is dynamically typed, but you can add type hints to make your code clearer,
# safer, and nicer for editors, linters, and teammates.

# %%
def add(a: int, b: int) -> int:
    return a + b

# %%
add(2, 3)  # Python chalega, typing sirf warning degi
# Out:
# 5

# %%
numbers: list[int] = [1, 2, 3]
names: dict[str, int] = {"alice": 1, "bob": 2}
tags: set[str] = {"python", "typing"}

# %%
import asyncio

async def task(name, delay):
    print(f"Task {name} started")
    await asyncio.sleep(delay)
    print(f"Task {name} finished")

async def main():
    await asyncio.gather(
        task("A", 2),
        task("B", 1),
    )

asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-44936386.py in <cell line: 0>()
#      12     )
#      13
# ---> 14 asyncio.run(main())
#
# /usr/lib/python3.12/asyncio/runners.py in run(main, debug, loop_factory)
#     189     if events._get_running_loop() is not None:
#     190         # fail fast with short traceback
# --> 191         raise RuntimeError(
#     192             "asyncio.run() cannot be called from a running event loop")
#     193
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %%
import asyncio

async def say_hello():
    print("Hello")
    await asyncio.sleep(1)
    print("World!")

# Top-level await in Colab
await say_hello()
# Out:
# Hello
# World!
